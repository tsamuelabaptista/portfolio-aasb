# %% [markdown]
# fazer os asserts (falta confirmar se estão certos e se não falta nenhum)
#
# fazer a documentação (falta confirmar se está certa e se não falta nada)
#
# fazer os testes unitários
#
# ajustar perfis probabilisticos (e acrescentar pssm)

# %%
def matriz_subst(nome_matriz:str) -> list[list[int]]:
    """
    Esta função abre e lê um destes ficheiros de texto: "BLOSSOM62.txt", "BLOSSOM80.txt", "PAM30.txt", "PAM70.txt" 
    e devolve a matriz de substituição retirada do ficheiro como uma matriz bidimensional, capaz de ser utilizada pela função "score_subst_prot".
    Esta função requer pelo menos um dos ficheiros "BLOSSOM62.txt", "BLOSSOM80.txt", "PAM30.txt", "PAM70.txt" na diretoria atual para funcionar.
    
    Parameters
    ----------
    nome_matriz:str
        Nome da matriz de substituição que se pretende que seja lida por esta função

    Returns
    -------
    matriz:list[list[int]]
        Matriz de substituição carregada a partir de um ficheiro de texto

    Raises
    ------
    AssertionError
        Quando o nome da matriz fornecido não corresponde às matrizes aceites pela função,
        sendo estas as seguintes: "BLOSSOM62", "BLOSSOM80", "PAM30", "PAM70"
    
    """
    assert nome_matriz.upper() in ["BLOSSOM62", "BLOSSOM80", "PAM30", "PAM70"],f"A matriz de substituição escolhida é inválida, apenas aceita as matrizes 'BLOSSOM62', 'BLOSSOM80', 'PAM30', 'PAM70'"
    with open(nome_matriz.upper()+".txt", "r") as file:
        matriz = []
        for line in file:
            line = line.strip()
            linha = []
            valor = ""
            for elem in line:
                if elem == " ":
                    if len(valor) != 0:
                        linha.append(valor)
                        valor = ""
                else:
                    valor += elem
            linha.append(valor)
            matriz.append(linha)
    return matriz

# %%
# matriz_subst("BLOSSOM62")

# %%
# for line in matriz_subst("BLOSSOM62"):
#     print(line,",", sep="")

# %%
def score_subst_prot(nome_matriz:str, aa1:str, aa2:str) -> int:
    """
    Esta função navega na matriz de substituição obtida através da função "matriz_subst" 
    e retorna o score correspondente ao ????alinhamento???? de dois dos seguintes caracteres: 
    'A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X','_',
    sendo que as letras representam os aminoácidos e o caracter '_' representa o codão stop.
    
    Parameters
    ----------
    nome_matriz:str
        Nome da matriz de substituição que se pretende que seja utilizada para fornecer os scores de substituição

    aa1:str
        Aminoácido cujo ????match???? vai ser procurado ao longo da primeira coluna

    aa2:str
        Aminoácido cujo ????match???? vai ser procurado ao longo da primeira linha

    Returns
    -------
    score:int
        Score obtido para o alinhamento dos dois aminoácidos na matriz de substituição

    Raises
    ------
    AssertionError
        Quando o caracter inserido correspondente ao 'aa1' não é válido como aminoácido ou codão stop

    AssertionError
        Quando o caracter inserido correspondente ao 'aa2' não é válido como aminoácido ou codão stop
    """
    aa1, aa2 = aa1.upper(), aa2.upper()
    lista_aminoacidos = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X','_']
    assert aa1 in lista_aminoacidos,f"O caracter {aa1} não é válido como aminoácido ou codão stop"
    assert aa2 in lista_aminoacidos,f"O caracter {aa2} não é válido como aminoácido ou codão stop"
    matriz = matriz_subst(nome_matriz)
    coluna = 0
    linha = 0
    for i in range(1,len(matriz)):
        if aa1 == matriz[i][0]:
            linha = i
            break
    for pos, elem in enumerate(matriz[0]):
        if elem == aa2:
            coluna = pos
            break
    score = matriz[linha][coluna]
    return score

# %%
# score_subst_prot("BLOSSOM62", "A", "A")

# %%
def score_subst_prot(nome_matriz:str, aa1:str, aa2:str) -> int:
    """
    Esta função abre e lê um destes ficheiros de texto: "BLOSSOM62.txt", "BLOSSOM80.txt", "PAM30.txt", "PAM70.txt" 
    retirando a matriz de substituição do ficheiro como uma matriz bidimensional.
    Depois navega na matriz de substituição obtida e retorna o score correspondente ao ????alinhamento???? de dois dos seguintes caracteres: 
    'A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X','_',
    sendo que as letras representam os aminoácidos e o caracter '_' representa o codão stop.
    
    Parameters
    ----------
    nome_matriz:str
        Nome da matriz de substituição que se pretende que seja lida e utilizada para fornecer os scores de substituição

    aa1:str
        Aminoácido cujo ????match???? vai ser procurado ao longo da primeira coluna da matriz de substituição

    aa2:str
        Aminoácido cujo ????match???? vai ser procurado ao longo da primeira linha da matriz de substituição

    Returns
    -------
    score:int
        Score obtido para o alinhamento dos dois aminoácidos na matriz de substituição

    Raises
    ------
    AssertionError
        Quando o nome da matriz fornecido não corresponde a uma das matrizes aceites pela função:
        "BLOSSOM62", "BLOSSOM80", "PAM30", "PAM70"

    AssertionError
        Quando o caracter inserido correspondente ao 'aa1' não é válido como aminoácido ou codão stop

    AssertionError
        Quando o caracter inserido correspondente ao 'aa2' não é válido como aminoácido ou codão stop
    """
    assert type(nome_matriz)==str,f"O argumento {nome_matriz} deve ser do tipo str"
    assert type(aa1)==str,f"O argumento {aa1} deve ser do tipo str"
    assert type(aa2)==str,f"O argumento {aa2} deve ser do tipo str"
    assert nome_matriz.upper() in ["BLOSSOM62", "BLOSSOM80", "PAM30", "PAM70"],"A matriz de substituição escolhida é inválida, apenas aceita as matrizes 'BLOSSOM62', 'BLOSSOM80', 'PAM30', 'PAM70'"
    with open(nome_matriz.upper()+".txt", "r") as file:
        matriz = []
        for line in file:
            line = line.strip()
            linha = []
            valor = ""
            for elem in line:
                if elem == " ":
                    if len(valor) != 0:
                        linha.append(valor)
                        valor = ""
                else:
                    valor += elem
            linha.append(valor)
            matriz.append(linha)
    aa1, aa2 = aa1.upper(), aa2.upper()
    lista_aminoacidos = ['A','R','N','D','C','Q','E','G','H','I','L','K','M','F','P','S','T','W','Y','V','B','J','Z','X','_']
    assert aa1 in lista_aminoacidos,f"O caracter {aa1} não é válido como aminoácido ou codão stop"
    assert aa2 in lista_aminoacidos,f"O caracter {aa2} não é válido como aminoácido ou codão stop"
    coluna, linha = 0, 0
    for i in range(1,len(matriz)):
        if aa1 == matriz[i][0]:
            linha = i
            break
    for pos, elem in enumerate(matriz[0]):
        if elem == aa2:
            coluna = pos
            break
    score = matriz[linha][coluna]
    return int(score)

# %%
score_subst_prot("BLOSSOM62", "h", "h")
# Out:
# 8

# %% [markdown]
# ### Testes de unidade

# %%
import unittest

class Test_matrizes_subst(unittest.TestCase):
    def test_score_subst_tipo_nome_matriz_invalido(self):
        with self.assertRaises(AssertionError):
            score_subst_prot(1, "A", "A")
        
    def test_score_subst_tipo_aa1_invalido(self):
        with self.assertRaises(AssertionError):
            score_subst_prot("BLOSSOM62", 1, "A")

    def test_score_subst_tipo_aa2_invalido(self):
        with self.assertRaises(AssertionError):
            score_subst_prot("BLOSSOM62", "A", 1)
    
    def test_score_subst_matriz_vazia(self):
        with self.assertRaises(AssertionError):
            score_subst_prot("", "A", "A")
            
    def test_score_subst_aa1_vazio(self):
        with self.assertRaises(AssertionError):
            score_subst_prot("BLOSSOM62", "", "A")

    def test_score_subst_aa2_vazio(self):
        with self.assertRaises(AssertionError):
            score_subst_prot("BLOSSOM62", "A", "")

    def test_score_subst_args_vazios(self):
        with self.assertRaises(AssertionError):
            score_subst_prot("", "", "")

    def test_score_subst_matriz_errada(self):
        with self.assertRaises(AssertionError):
            score_subst_prot("BLOSSOM70", "A", "A")

    def test_score_subst_aa1_errado(self):
        with self.assertRaises(AssertionError):
            score_subst_prot("BLOSSOM62", "-", "A")

    def test_score_subst_aa2_errado(self):
        with self.assertRaises(AssertionError):
            score_subst_prot("BLOSSOM62", "A", "-")

    def test_score_subst_letras_maiusculas(self):
        self.assertEqual(score_subst_prot("BLOSSOM62", "A", "A"), 4)

    def test_score_subst_letras_minusculas(self):
        self.assertEqual(score_subst_prot("blossom62", "a", "a"), 4)

    def test_score_subst_blossom62_correto(self):
        aa1=['A', 'H', '_', 'A', 'H', 'A', '_']
        aa2=['A', 'H', '_', 'H', 'A', '_', 'A']
        scores=[4, 8, 1, -2, -2, -4, -4]
        for x,y,z in zip(aa1,aa2,scores):
            self.assertEqual(score_subst_prot("BLOSSOM62", x, y), z)

    def test_score_subst_blossom62_incorreto(self):
        aa1=['A', 'H', '_', 'A', 'H', 'A', '_']
        aa2=['A', 'H', '_', 'H', 'A', '_', 'A']
        scores=[3, 6, 2, -1, -1, -2, -2]
        for x,y,z in zip(aa1,aa2,scores):
            self.assertNotEqual(score_subst_prot("BLOSSOM62", x, y), z)

    def test_score_subst_blossom80_correto(self):
        aa1=['A', 'H', '_', 'A', 'H', 'A', '_']
        aa2=['A', 'H', '_', 'H', 'A', '_', 'A']
        scores=[5, 8, 1, -2, -2, -6, -6]
        for x,y,z in zip(aa1,aa2,scores):
            self.assertEqual(score_subst_prot("BLOSSOM80", x, y), z)

    def test_score_subst_blossom80_incorreto(self):
        aa1=['A', 'H', '_', 'A', 'H', 'A', '_']
        aa2=['A', 'H', '_', 'H', 'A', '_', 'A']
        scores=[4, 6, 2, -1, -1, -3, -3]
        for x,y,z in zip(aa1,aa2,scores):
            self.assertNotEqual(score_subst_prot("BLOSSOM80", x, y), z)

    def test_score_subst_pam30_correto(self):
        aa1=['A', 'H', '_', 'A', 'H', 'A', '_']
        aa2=['A', 'H', '_', 'H', 'A', '_', 'A']
        scores=[6, 9, 1, -7, -7, -17, -17]
        for x,y,z in zip(aa1,aa2,scores):
            self.assertEqual(score_subst_prot("PAM30", x, y), z)

    def test_score_subst_pam30_incorreto(self):
        aa1=['A', 'H', '_', 'A', 'H', 'A', '_']
        aa2=['A', 'H', '_', 'H', 'A', '_', 'A']
        scores=[4, 7, 2, -5, -5, -12, -12]
        for x,y,z in zip(aa1,aa2,scores):
            self.assertNotEqual(score_subst_prot("PAM30", x, y), z)

    def test_score_subst_pam70_correto(self):
        aa1=['A', 'H', '_', 'A', 'H', 'A', '_']
        aa2=['A', 'H', '_', 'H', 'A', '_', 'A']
        scores=[5, 8, 1, -4, -4, -11, -11]
        for x,y,z in zip(aa1,aa2,scores):
            self.assertEqual(score_subst_prot("PAM70", x, y), z)
        
    def test_score_subst_pam70_incorreto(self):
        aa1=['A', 'H', '_', 'A', 'H', 'A', '_']
        aa2=['A', 'H', '_', 'H', 'A', '_', 'A']
        scores=[3, 6, 2, -2, -2, -8, -8]
        for x,y,z in zip(aa1,aa2,scores):
            self.assertNotEqual(score_subst_prot("PAM70", x, y), z)

suite = unittest.TestLoader().loadTestsFromTestCase(Test_matrizes_subst)
unittest.TextTestRunner(verbosity=3).run(suite)
# Out:
# test_score_subst_aa1_errado (__main__.Test_matrizes_subst) ... ok
# test_score_subst_aa1_vazio (__main__.Test_matrizes_subst) ... ok
# test_score_subst_aa2_errado (__main__.Test_matrizes_subst) ... ok
# test_score_subst_aa2_vazio (__main__.Test_matrizes_subst) ... ok
# test_score_subst_args_vazios (__main__.Test_matrizes_subst) ... ok
# test_score_subst_blossom62_correto (__main__.Test_matrizes_subst) ... ok
# test_score_subst_blossom62_incorreto (__main__.Test_matrizes_subst) ... ok
# test_score_subst_blossom80_correto (__main__.Test_matrizes_subst) ... ok
# test_score_subst_blossom80_incorreto (__main__.Test_matrizes_subst) ... ok
# test_score_subst_letras_maiusculas (__main__.Test_matrizes_subst) ... ok
# test_score_subst_letras_minusculas (__main__.Test_matrizes_subst) ... ok
# test_score_subst_matriz_errada (__main__.Test_matrizes_subst) ... ok
# test_score_subst_matriz_vazia (__main__.Test_matrizes_subst) ... ok
# test_score_subst_pam30_correto (__main__.Test_matrizes_subst) ... ok
# test_score_subst_pam30_incorreto (__main__.Test_matrizes_subst) ... ok
# test_score_subst_pam70_correto (__main__.Test_matrizes_subst) ... ok
# test_score_subst_pam70_incorreto (__main__.Test_matrizes_subst) ... ok
# test_score_subst_tipo_aa1_invalido (__main__.Test_matrizes_subst) ... ok
# test_score_subst_tipo_aa2_invalido (__main__.Test_matrizes_subst) ... ok
# test_score_subst_tipo_nome_matriz_invalido (__main__.Test_matrizes_subst) ... ok
#
# ----------------------------------------------------------------------
# Ran 20 tests in 0.104s
#
# OK
# <unittest.runner.TextTestResult run=20 errors=0 failures=0>
